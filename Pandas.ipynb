# %%
import pandas as pd

data = { "Name ":["A","B","C"],
        "Age":[12,3,4],
        "Salary":[2333,8909,1234]}

mx = pd.DataFrame(data)
print(mx)
# Out:
#   Name   Age  Salary
# 0     A   12    2333
# 1     B    3    8909
# 2     C    4    1234

# %%
data = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\Excel Projects\First Project.xlsx")
print(data.head(5))
print(data.tail())
# Out:
#   Empoyee Payroll    Mr. Faizer           Unnamed: 2           Unnamed: 3  \
# 0             NaN           NaN         House Worked                  NaN
# 1            Name  Hours Wages   2023-01-01 00:00:00  2023-01-08 00:00:00
# 2           Karim            15                   24                   21
# 3           Rahim          22.5                   21                   34
# 4            Mr.X          25.2                   26                   34
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1  2023-01-15 00:00:00  2023-01-22 00:00:00  2023-01-29 00:00:00
# 2                   21                   29                   21
# 3                   32                   27                   32
# 4                   34                   26                   34
#
#             Unnamed: 7           Unnamed: 8           Unnamed: 9  ...  \
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Empoyee Payroll  17 non-null     object
#  1   Mr. Faizer       17 non-null     object
#  2   Unnamed: 2       18 non-null     object
#  3   Unnamed: 3       17 non-null     object
#  4   Unnamed: 4       17 non-null     object
#  5   Unnamed: 5       17 non-null     object
#  6   Unnamed: 6       17 non-null     object
#  7   Unnamed: 7       18 non-null     object
#  8   Unnamed: 8       17 non-null     object
#  9   Unnamed: 9       17 non-null     object
#  10  Unnamed: 10      17 non-null     object
#  11  Unnamed: 11      17 non-null     object
#  12  Unnamed: 12      18 non-null     object
#  13  Unnamed: 13      17 non-null     object
#  14  Unnamed: 14      17 non-null     object
#  15  Unnamed: 15      17 non-null     object
#  16  Unnamed: 16      17 non-null     object
# ...

# %%
data.describe()
# Out:
#        Empoyee Payroll  Mr. Faizer  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# count               17          17          18          17          17
# unique              17          15          12          10          12
# top               Name          10          21          21          32
# freq                 1           2           4           4           3
#
#         Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# count           17          17          18          17          17  ...
# unique          11          10          12           9           9  ...
# top             32          21           0           0           0  ...
# freq             4           4           4           6           5  ...
#
#         Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# count            17           17           17           17         18.0
# unique           11           12           14           12         16.0
# ...

# %%
print(data.isnull().sum())
# Out:
# Empoyee Payroll    3
# Mr. Faizer         3
# Unnamed: 2         2
# Unnamed: 3         3
# Unnamed: 4         3
# Unnamed: 5         3
# Unnamed: 6         3
# Unnamed: 7         2
# Unnamed: 8         3
# Unnamed: 9         3
# Unnamed: 10        3
# Unnamed: 11        3
# Unnamed: 12        2
# Unnamed: 13        3
# Unnamed: 14        3
# Unnamed: 15        3
# Unnamed: 16        3
# Unnamed: 17        2
# Unnamed: 18        3
# Unnamed: 19        3
# Unnamed: 20        3
# Unnamed: 21        3
# Unnamed: 22        2
# Unnamed: 23        3
# Unnamed: 24        3
# Unnamed: 25        3
# Unnamed: 26        3
# Unnamed: 27        3
# dtype: int64

# %%
print(data.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
data = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\Excel Projects\Second Project.xlsx")
print (data)
# Out:
#    Unnamed: 0    Name   age  Class
# 0         NaN    Hello    21     A
# 1         NaN  Helelna    21     A
# 2         NaN    Aegon    26     A
# 3         NaN  Alicent    35     A
# 4         NaN    Amond    22     A

# %%
data.describe()
# Out:
#        Unnamed: 0       age
# count         0.0   5.000000
# mean          NaN  25.000000
# std           NaN   5.958188
# min           NaN  21.000000
# 25%           NaN  21.000000
# 50%           NaN  22.000000
# 75%           NaN  26.000000
# max           NaN  35.000000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Name        5 non-null      object
#  2   age         5 non-null      int64
#  3   Class       5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes
# None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Name        5 non-null      object
#  2   age         5 non-null      int64
#  3   Class       5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
print(data.duplicated().sum())
# Out:
# 0
